# %% [markdown]
# # <center> Pandas Tutorial </center>
#
# 🔹 Introduction to Pandas
#
# Pandas is a Python library widely used for data manipulation and analysis.
# It provides two main data structures:
#
# Series → 1D labeled array (like a single column).
#
# DataFrame → 2D labeled table (like an Excel sheet)

# %%
# Install pandas (if not installed already)
# !pip install pandas

# Import pandas with alias
import pandas as pd
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# 🔹 1. Pandas Series
#
# A Series is a one-dimensional labeled array.
#
# It can hold data of any type: integers, floats, strings, etc.
#
# Think of it as one column of data in a spreadsheet.

# %%
import pandas as pd

# Creating a Series from a Python list
scores = [85, 90, 78, 92]
series_scores = pd.Series(scores)

print(series_scores)
# Out:
# 0    85
# 1    90
# 2    78
# 3    92
# dtype: int64

# %% [markdown]
# 👉 The left side (0, 1, 2, 3) is the index.
#
# 👉 The right side (85, 90, 78, 92) is the data.

# %% [markdown]
# ✅ Custom Index in Series
#
# We can provide custom labels instead of default numeric index.

# %%
marks = pd.Series([85, 90, 78, 92], index=["Math", "Science", "History", "English"])
print(marks)
# Out:
# Math       85
# Science    90
# History    78
# English    92
# dtype: int64

# %% [markdown]
# 🔹 2. Pandas DataFrame
#
# A DataFrame is a two-dimensional table of rows and columns.
#
# It’s like a spreadsheet or SQL table.
#
# Each column in a DataFrame is actually a Series.

# %%
# Creating a DataFrame from a dictionary
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 22],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78

# %% [markdown]
# 🔹 Series vs DataFrame – Key Differences
#
# | Feature   | **Series**              | **DataFrame**                  |
# | --------- | ----------------------- | ------------------------------ |
# | Dimension | 1D                      | 2D                             |
# | Structure | Single column           | Rows × Columns (table)         |
# | Indexing  | Single axis (index)     | Two axes (rows + columns)      |
# | Example   | Student’s marks in Math | Student info: Name, Age, Marks |
# | Analogy   | A column in Excel       | A whole Excel sheet            |

# %% [markdown]
# **🔹 Accessing Data**
#
# ✅ Accessing Elements in Series

# %%
marks = pd.Series([85, 90, 78, 92], index=["Math", "Science", "History", "English"])
print(marks)
# print("Math Marks:", marks["Math"])   # By label - 1
print("First Element:", marks[0])     # By index -2
# Out:
# Math       85
# Science    90
# History    78
# English    92
# dtype: int64
# First Element: 85
# /tmp/ipython-input-1132615196.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("First Element:", marks[0])     # By index -2

# %% [markdown]
# ✅ Accessing Data in DataFrame

# %%
# Creating a DataFrame from a dictionary
data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 22],
    "Marks": [85, 90, 78]
}

df = pd.DataFrame(data)
# print(df)


# Access a column (returns a Series)
print(df["Name"])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
# Access multiple columns
print(df[["Name", "Marks"]])
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
print(df)
# Access a row using index
print(df.loc[0])   # By label
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# Name     Alice
# Age         25
# Marks       85
# Name: 0, dtype: object

# %%
print(df)

print(df.iloc[0])  # By position
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# Name     Alice
# Age         25
# Marks       85
# Name: 0, dtype: object

# %% [markdown]
# 📌 Difference Between .loc and .iloc
# | Feature        | `.loc`                                  | `.iloc`                          |
# | -------------- | --------------------------------------- | -------------------------------- |
# | **Index type** | Label-based indexing                    | Integer position-based indexing  |
# | **Usage**      | Use row **labels** and column **names** | Use row and column **positions** |
# | **Inclusive**  | End index is **inclusive**              | End index is **exclusive**       |

# %% [markdown]
# 🧠 .loc[] – Label-based indexing

# %% [markdown]
# It uses row labels and column names.
#
# ✅ Examples:
# 1. Get the row where the index label is 1:

# %%
print(df)
df.loc[1]
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# Name     Bob
# Age       30
# Marks     90
# Name: 1, dtype: object

# %% [markdown]
# 2. Get rows 0 and 2:

# %%
print(df)
df.loc[[0, 2]]
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
#       Name  Age  Marks
# 0    Alice   25     85
# 2  Charlie   22     78

# %%
print(df)
# Create DataFrame with custom row labels
df = pd.DataFrame(data, index=['a', 'b', 'c'])
print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
#       Name  Age  Marks
# a    Alice   25     85
# b      Bob   30     90
# c  Charlie   22     78

# %%
# ✅ Access row with label 'b':
# df.loc['b'] # try
df.loc[['b']] #- for row view
# Out:
#   Name  Age  Marks
# b  Bob   30     90

# %% [markdown]
# 🧠 .iloc[] – Integer position-based indexing
#
# It uses integer indexes, similar to how Python lists work.
#
# ✅ Examples:
# 1. Get the first row (position 0):

# %%
df.iloc[0]
# Out:
# Name     Alice
# Age         25
# Marks       85
# Name: a, dtype: object

# %% [markdown]
# 2. Get the first two rows:

# %%
df.iloc[0:2]  # end is exclusive
# Out:
#     Name  Age  Marks
# a  Alice   25     85
# b    Bob   30     90

# %% [markdown]
# 3. Get the second column (Age) for first and third row:

# %%
# Get the second column (Age) for first and third row:
print(df)
df.iloc[[0, 2], 1]
# Out:
#       Name  Age  Marks
# a    Alice   25     85
# b      Bob   30     90
# c  Charlie   22     78
# a    25
# c    22
# Name: Age, dtype: int64

# %% [markdown]
# 🆚 Summary Table
# | What you want to do                     | Use    | Example                          |
# | --------------------------------------- | ------ | -------------------------------- |
# | Get data by label (e.g., row index = 1) | `loc`  | `df.loc[1]`                      |
# | Get data by position (e.g., first row)  | `iloc` | `df.iloc[0]`                     |
# | Slice by row label and column name      | `loc`  | `df.loc[0:2, ['Name', 'Marks']]` |
# | Slice by row/column number (position)   | `iloc` | `df.iloc[0:3, 1:3]`              |

# %% [markdown]
# 🔹 Converting Series → DataFrame
#
# Sometimes we want to convert a Series into a DataFrame

# %%
marks = pd.Series([85, 90, 78, 92], index=["Math", "Science", "History", "English"])
print(marks)
print(type(marks))
# Out:
# Math       85
# Science    90
# History    78
# English    92
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# Convert Series to DataFrame
marks_df = marks.to_frame(name="Marks")
print(marks_df)
print(type(marks_df))
# Out:
#          Marks
# Math        85
# Science     90
# History     78
# English     92
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# 🔹 Real-Life Example
#
# Imagine student records:
#
# Series → One subject’s marks of students.
#
# DataFrame → Complete student report with name, age, marks, and grade.

# %%
# Series example
math_marks = pd.Series([85, 90, 78], index=["Alice", "Bob", "Charlie"])
print("Math Marks (Series):\n", math_marks)
# Out:
# Math Marks (Series):
#  Alice      85
# Bob        90
# Charlie    78
# dtype: int64

# %%
# DataFrame example
student_data = {
    "Name": ["Alice", "Bob", "Charlie"],
    "Age": [25, 30, 22],
    "Math": [85, 90, 78],
    "Science": [88, 92, 80]

}
df_students = pd.DataFrame(student_data)
print("\nStudent Data (DataFrame):\n", df_students)
# Out:
# Student Data (DataFrame):
#        Name  Age  Math  Science
# 0    Alice   25    85       88
# 1      Bob   30    90       92
# 2  Charlie   22    78       80

# %% [markdown]
# ###🔹 Summary
#
# - Series = 1D labeled array (like a single column).
#
# - DataFrame = 2D table of rows and columns (like a full dataset).
#
# - DataFrame is built from multiple Series.
#
# - Use Series for one column of data, DataFrame for complete datasets.

# %% [markdown]
# #Filtering Data in Pandas

# %%
import pandas as pd

# Sample DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 22, 28],
    "Marks": [85, 90, 78, 92]
}

df = pd.DataFrame(data)

# Select single column
# print(df["Name"])
print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# 3    David   28     92

# %% [markdown]
# 🔹 Filtering Data (Applying Conditions)
#
# Filtering lets us extract rows that satisfy certain conditions.
#
# ✅ Example 1: Students older than 25

# %%
print(df)
print(df[df["Age"] > 25])
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# 3    David   28     92
#     Name  Age  Marks
# 1    Bob   30     90
# 3  David   28     92

# %% [markdown]
# ✅ Example 2: Students with Marks ≥ 90

# %%
print(df[df["Marks"] >= 90])
# Out:
#     Name  Age  Marks
# 1    Bob   30     90
# 3  David   28     92

# %% [markdown]
# ✅ Example 3: Combining Multiple Conditions
#
# Use & (AND) and | (OR) operators.
#
# 👉 Remember to wrap each condition in parentheses

# %%
# Students older than 25 AND Marks above 85
print(df[(df["Age"] > 25) & (df["Marks"] > 85)])
# Out:
#     Name  Age  Marks
# 1    Bob   30     90
# 3  David   28     92

# %% [markdown]
# ✅ Example 4: Filtering by String Matching

# %% [markdown]
# 🔍 .str.startswith("A") is case-sensitive
#
# This means it will match:
#
# ✅ "Alice"
#
# ❌ "alice"

# %%
print(df)
# Names starting with 'A'
print(df[df["Name"].str.startswith("A")])
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# 3    David   28     92
#     Name  Age  Marks
# 0  Alice   25     85

# %% [markdown]
# ✅ To make it case-insensitive, use .str.lower()
#
# df[df["Name"].str.lower().str.startswith("a")]

# %%
df[df["Name"].str.lower().str.startswith("a")]
# Out:
#     Name  Age  Marks
# 0  Alice   25     85

# %% [markdown]
# ✅ Example 5: Filtering with .isin()
#
# Check if a column’s values are in a list.

# %%
# Select students whose names are Alice or David
print(df[df["Name"].isin(["Alice", "David"])])
# Out:
#     Name  Age  Marks
# 0  Alice   25     85
# 3  David   28     92

# %% [markdown]
# ###🔹 Summary of Selection/Filtering
#
# - Column Selection → df["col"] or df[["col1","col2"]]
#
# - Row Selection → .loc[] (label) and .iloc[] (position)
#
# - Filtering → df[condition]
#
# - Combine conditions with & (AND), | (OR)
#
# - Use .str for string conditions
#
# - Use .isin() for multiple values

# %% [markdown]
# #Manipulating Tabular Data in Pandas

# %% [markdown]
# 🔹 Step 1: Create a Sample DataFrame

# %%
import pandas as pd

# Sample DataFrame
data = {
    "Name": ["Alice", "Bob", "Charlie", "David"],
    "Age": [25, 30, 22, 28],
    "Marks": [85, 90, 78, 92]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Marks
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   22     78
# 3    David   28     92

# %% [markdown]
# 🔹 Step 2: Adding New Columns
#
# You can create new columns using calculations or external data.

# %%
# Add a new column: Grade
df["Grade"] = ["B", "A", "C", "A"]

# Add a column based on condition
df["Pass"] = df["Marks"] >= 80

print(df)
# Out:
#       Name  Age  Marks Grade   Pass
# 0    Alice   25     85     B   True
# 1      Bob   30     90     A   True
# 2  Charlie   22     78     C  False
# 3    David   28     92     A   True

# %% [markdown]
# 🔹 Step 3: Updating Values

# %%
# Update single value
# .at[row_label, column_name] is used for fast access to a single value.
# Works only with label-based access, not integer positions.
# Faster than .loc when working with a single cell.
df.at[2, "Marks"] = 72   # Charlie’s marks updated
print(df)
# Out:
#       Name  Age  Marks Grade   Pass
# 0    Alice   25     85     B   True
# 1      Bob   30     90     A   True
# 2  Charlie   22     72     C  False
# 3    David   28     92     A   True

# %%
# Update entire column (increase all ages by 1)
df["Age"] = df["Age"] + 1
print(df)
# Out:
#       Name  Age  Marks Grade   Pass
# 0    Alice   26     85     B   True
# 1      Bob   31     90     A   True
# 2  Charlie   23     72     C  False
# 3    David   29     92     A   True

# %% [markdown]
# 🔹 Step 4: Removing Columns and Rows

# %%
# Drop a column
# Calls the .drop() method on the DataFrame df, which removes rows or columns.
df = df.drop("Grade",axis=1) # If you forget axis=1, pandas will assume you're trying to drop a row

# Drop a row (by index)
df = df.drop(0)   # removes Alice’s row
print(df)
# Out:
#       Name  Age  Marks   Pass
# 1      Bob   31     90   True
# 2  Charlie   23     72  False
# 3    David   29     92   True

# %% [markdown]
# 🔹 Step 5: Renaming Columns

# %%
df = df.rename(columns={"Marks": "Score"}) #Means: change column name "Marks" → "Score".
print(df)
# Out:
#       Name  Age  Score   Pass
# 1      Bob   31     90   True
# 2  Charlie   23     72  False
# 3    David   29     92   True

# %% [markdown]
# 🔹 Step 6: Sorting Data

# %%
# Sort by Score (ascending)
# print(df.sort_values(by="Score"))

# # Sort by Age (descending)
#  the sort_values() function to sort a DataFrame by a specific column — in this case, "Age" — in descending order.
print(df.sort_values(by="Age", ascending=False))
# Out:
#       Name  Age  Score   Pass
# 1      Bob   31     90   True
# 3    David   29     92   True
# 2  Charlie   23     72  False

# %% [markdown]
# 🔹 Step 7: Grouping Data
#
# Grouping helps summarize data.

# %%
# Group by Pass status and calculate average score
grouped = df.groupby("Pass")["Score"].mean()
print(grouped)
# Out:
# Pass
# False    72.0
# True     91.0
# Name: Score, dtype: float64

# %% [markdown]
# 🔹 Step 8: Aggregations

# %%
# print("Mean Age:", df["Age"].mean())
# print("Max Score:", df["Score"].max())
# print("Min Score:", df["Score"].min())
print("Summary:\n", df.describe())
# Out:
# Summary:
#               Age      Score
# count   3.000000   3.000000
# mean   27.666667  84.666667
# std     4.163332  11.015141
# min    23.000000  72.000000
# 25%    26.000000  81.000000
# 50%    29.000000  90.000000
# 75%    30.000000  91.000000
# max    31.000000  92.000000

# %% [markdown]
# 🔹 Step 9: Handling Missing Data

# %%
# Introduce missing value
df.loc[1, "Score"] = None
print(df)

# Fill missing values with average
df["Score"].fillna(df["Score"].mean(), inplace=True)
print(df)

# Drop rows with missing values
df.dropna(inplace=True)
# Out:
#       Name  Age  Score   Pass
# 1      Bob   31    NaN   True
# 2  Charlie   23   72.0  False
# 3    David   29   92.0   True
#       Name  Age  Score   Pass
# 1      Bob   31   82.0   True
# 2  Charlie   23   72.0  False
# 3    David   29   92.0   True
# /tmp/ipython-input-661357108.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Score"].fillna(df["Score"].mean(), inplace=True)

# %% [markdown]
# 🔹 Summary of Data Manipulation
#
# Add column → df["new"] = ...
#
# Update value → df.at[row, "col"]
#
# Drop column/row → df.drop()
#
# Rename → df.rename()
#
# Sort → df.sort_values()
#
# Group/Aggregate → df.groupby() + mean(), sum(), etc.

# %% [markdown]
# #Summarizing Data in Pandas: groupby & describe

# %% [markdown]
# 🔹 Step 1: Create a Sample DataFrame

# %%
import pandas as pd

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva"],
    "Department": ["HR", "IT", "HR", "Finance", "IT"],
    "Salary": [50000, 60000, 52000, 58000, 62000],
    "Experience": [2, 5, 3, 7, 4]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name Department  Salary  Experience
# 0    Alice         HR   50000           2
# 1      Bob         IT   60000           5
# 2  Charlie         HR   52000           3
# 3    David    Finance   58000           7
# 4      Eva         IT   62000           4

# %% [markdown]
# 🔹 Step 2: Using groupby()
#
# groupby() helps to group rows based on a column and apply aggregations (mean, sum, count, etc.).
#
# ✅ Example 1: Average Salary by Department

# %%
avg_salary = df.groupby("Department")["Salary"].mean()
print(avg_salary)
# Out:
# Department
# Finance    58000.0
# HR         51000.0
# IT         61000.0
# Name: Salary, dtype: float64

# %% [markdown]
# ✅ Example 2: Multiple Aggregations

# %%
summary = df.groupby("Department").agg({
    "Salary": ["mean", "max", "min"],
    "Experience": "mean"
})
print(summary)
# Out:
#              Salary               Experience
#                mean    max    min       mean
# Department
# Finance     58000.0  58000  58000        7.0
# HR          51000.0  52000  50000        2.5
# IT          61000.0  62000  60000        4.5

# %% [markdown]
# 🔹 Step 3: Using describe()
#
# describe() provides a statistical summary of numeric columns.

# %%
print(df.describe())
# Out:
#              Salary  Experience
# count      5.000000    5.000000
# mean   56400.000000    4.200000
# std     5176.871642    1.923538
# min    50000.000000    2.000000
# 25%    52000.000000    3.000000
# 50%    58000.000000    4.000000
# 75%    60000.000000    5.000000
# max    62000.000000    7.000000

# %% [markdown]
# 🔹 Step 4: Groupby + Describe
#
# We can even combine both!

# %%
# Groups the DataFrame by unique values in the "Department" column.Focuses on the "Salary" column within each group.
dept_summary = df.groupby("Department")["Salary"].describe()
print(dept_summary)
# Out:
#             count     mean          std      min      25%      50%      75%  \
# Department
# Finance       1.0  58000.0          NaN  58000.0  58000.0  58000.0  58000.0
# HR            2.0  51000.0  1414.213562  50000.0  50500.0  51000.0  51500.0
# IT            2.0  61000.0  1414.213562  60000.0  60500.0  61000.0  61500.0
#
#                 max
# Department
# Finance     58000.0
# HR          52000.0
# IT          62000.0

# %% [markdown]
# 🔹 Summary
#
# groupby() → Groups rows and applies aggregation (mean, sum, count, etc.).
#
# agg() → Allows multiple aggregations on different columns.
#
# describe() → Gives descriptive statistics (count, mean, std, min, quartiles, max).
#
# groupby() + describe() → Combines grouping and summary statistics.
